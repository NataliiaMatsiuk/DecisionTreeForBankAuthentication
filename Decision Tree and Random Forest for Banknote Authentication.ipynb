# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read csv-file with data

# %%
df = pd.read_csv('csv_result-php50jXam.csv',index_col=0)

# %%
df.head()
# Out:
#          V1      V2      V3       V4  Class
# id
# 1   3.62160  8.6661 -2.8073 -0.44699      1
# 2   4.54590  8.1674 -2.4586 -1.46210      1
# 3   3.86600 -2.6383  1.9242  0.10645      1
# 4   3.45660  9.5228 -4.0112 -3.59440      1
# 5   0.32924 -4.4552  4.5718 -0.98880      1

# %% [markdown]
# Biuld a pairplot to see relationships between variables

# %%
sns.pairplot(df, hue='Class')

# %% [markdown]
# Divide dataset into train and test subsets

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Class',axis=1)
y=df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# Import DecisionTreeClassifier from sklearn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %% [markdown]
# Fit model

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Predict values by usind our model

# %%
pred = dtree.predict(X_test)

# %% [markdown]
# Import classification_report and confusion_matrix from sklearn to evaluate model

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[255   2]
#  [  6 190]]
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98       257
#            2       0.99      0.97      0.98       196
#
#     accuracy                           0.98       453
#    macro avg       0.98      0.98      0.98       453
# weighted avg       0.98      0.98      0.98       453

# %% [markdown]
# The results are good. We have precision, recall and f1-score equal to 0.98. It is pretty high level

# %% [markdown]
# Lets implement Random Forest Classifier to see if the results will be better

# %% [markdown]
# Import RandomForestClassifier from sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %% [markdown]
# Fit the model

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %% [markdown]
# Predict

# %%
pred = rfc.predict(X_test)

# %% [markdown]
# Print out classification_report and confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[257   0]
#  [  3 193]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       257
#            2       1.00      0.98      0.99       196
#
#     accuracy                           0.99       453
#    macro avg       0.99      0.99      0.99       453
# weighted avg       0.99      0.99      0.99       453

# %% [markdown]
# As we can see Random Forest Classifier is better, as well as precision, recall and f1-score equal 0.99.
# But both of models are very good.
